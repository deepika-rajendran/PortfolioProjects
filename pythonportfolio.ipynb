# %% [markdown]
# <a href="https://colab.research.google.com/github/deepika-rajendran/PortfolioProjects/blob/main/pythonportfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
from matplotlib import pyplot as plt
from importlib import reload
plt=reload(plt)
import seaborn as sns

# %%
ipl= pd.read_csv('matches.csv' )

# %%
ipl.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl.shape
# Out:
# (756, 18)

# %%
ipl['player_of_match'].value_counts()[0:5]
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# Name: player_of_match, dtype: int64

# %%
ipl['player_of_match'].value_counts()[0:5].keys()
# Out:
# Index(['CH Gayle', 'AB de Villiers', 'RG Sharma', 'MS Dhoni', 'DA Warner'], dtype='object')

# %%
#Finding the TOP 5 Man the match from(2008-2019)
plt.bar((ipl['player_of_match'].value_counts()[0:5].keys()),(ipl['player_of_match'].value_counts()[0:5]),color='orange')
plt.title("TOP 5 Highest Man of the Match Playes")
# Out:
# Text(0.5, 1.0, 'TOP 5 Highest Man of the Match Playes')

# %%
#Frequency of the result
ipl['result'].value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
#Frequency of the toss winner and loser
ipl['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
Batting_first=ipl[ipl['win_by_runs']!=0]

# %%
Batting_first.head()
# Out:
#     id    Season       city        date                        team1  \
# 0    1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4    5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 8    9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 13  14  IPL-2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14  15  IPL-2017      Delhi  15-04-2017             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 14              Kings XI Punjab             Delhi Daredevils           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# ...

# %%
plt.hist(Batting_first['win_by_runs'])
plt.title("Batting first winners")
plt.show()
#Batting first winners

# %%
#No of win with respect each team after batting first
Batting_first['winner'].value_counts()
# Out:
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            30
# Rajasthan Royals               27
# Delhi Daredevils               25
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Delhi Capitals                  3
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
plt.figure(figsize = (12,8))
plt.pie((Batting_first['winner'].value_counts()),labels=Batting_first['winner'].value_counts().keys(),autopct="%0.1f")
plt.title("Most No of Wins While Batting First")
# Out:
# Text(0.5, 1.0, 'Most No of Wins While Batting First')

# %%
Batting_Second=ipl[ipl['win_by_wickets']!=0]

# %%
plt.hist(Batting_Second['win_by_wickets'])
plt.title("Winners While Batting First")
plt.show()

# %%
Batting_Second['winner'].value_counts()
# Out:
# Kolkata Knight Riders          56
# Mumbai Indians                 50
# Royal Challengers Bangalore    48
# Chennai Super Kings            48
# Rajasthan Royals               46
# Kings XI Punjab                42
# Delhi Daredevils               42
# Sunrisers Hyderabad            27
# Gujarat Lions                  12
# Deccan Chargers                11
# Pune Warriors                   6
# Delhi Capitals                  6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
plt.figure(figsize = (12,8))
plt.pie((Batting_Second['winner'].value_counts()),labels=Batting_Second['winner'].value_counts().keys(),autopct="%0.1f")
plt.title('Most No of Wins While Batting Second')
# Out:
# Text(0.5, 1.0, 'Most No of Wins While Batting Second')

# %%
#No of match played for each season
ipl['Season'].value_counts()
# Out:
# IPL-2013    76
# IPL-2012    74
# IPL-2011    73
# IPL-2010    60
# IPL-2014    60
# IPL-2016    60
# IPL-2018    60
# IPL-2019    60
# IPL-2017    59
# IPL-2015    59
# IPL-2008    58
# IPL-2009    57
# Name: Season, dtype: int64

# %%
ipl.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
sum(ipl['winner']==ipl['toss_winner'])
# Out:
# 393

# %%
(ipl['winner']==ipl['toss_winner']).value_counts()
# Out:
# True     393
# False    363
# dtype: int64

# %%
toss=(ipl['winner']==ipl['toss_winner'])

# %%
toss_=sum(ipl['winner']==ipl['toss_winner'])
notoss=sum(ipl['winner']!=ipl['toss_winner'])

# %%
plt.pie((ipl['winner']==ipl['toss_winner']).value_counts(),labels=(393,363))
plt.title('No of Wins While winning the toss vs losing the toss ')
# Out:
# Text(0.5, 1.0, 'No of Wins While winning the toss vs losing the toss ')
